# %% [markdown]
# ## 1. Let's first import NumPy and matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %% [markdown]
# ## 2. We then draw several curves with matplotlib

# %%
np.random.seed(12)
for i in range(8):
    x = np.arange(1000)
    y = np.random.randn(1000).cumsum()
plt.plot(x, y, label=str(i))
plt.legend()

# %% [markdown]
# ### 3. Now, we create the exact same plot with prettyplotlib. We just replace the matplotlib.pyplot namespace with prettyplotlib.

# %%
import prettyplotlib as ppl
np.random.seed(12)
for i in range(8):
    x = np.arange(1000)
    y = np.random.randn(1000).cumsum()
ppl.plot(x, y, label=str(i))
ppl.legend()
# Out:
# /home/zhubolong/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py:878: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# /home/zhubolong/anaconda3/lib/python3.5/site-packages/matplotlib/legend.py:297: VisibleDeprecationWarning: using a boolean instead of an integer will result in an error in the future
#   reps)[:self.scatterpoints]

# %% [markdown]
# ## 4. Let's show another example with an image. We first use matplotlib's pcolormesh() function to display a 2D array as an image.

# %%
np.random.seed(12)
plt.pcolormesh(np.random.rand(16, 16))
plt.colorbar()

# %% [markdown]
# ## 5. Now, we use prettyplotlib to display the exact same image.

# %%
np.random.seed(12)
ppl.pcolormesh(np.random.rand(16, 16))
